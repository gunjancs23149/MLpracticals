# %% [markdown]
# <a href="https://colab.research.google.com/github/gunjancs23149/MLpracticals/blob/main/practical_10ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AIM:To perform hirerchical clustering using agglomerative methods and interpret dendrograms for clusterr formation.

# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt
import seaborn as sns

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram,linkage
from sklearn.preprocessing import StandardScaler

# %%
X=df[['Annual Income(k$)','Spending Score(1-100)']]

# %%
scalar=StandardScaler()
X_scaled=scalar.fit_transform(X)

# %%
plt.figure(figsize=(8,5)
dendrogram(linkage(df,method='ward')
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
hc=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
clusters=hc.fit_predict(X_scaled)

# %%
df['Cluster']=clusters
print(df.head())

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Annual Income (k$)',y='Spending Score (1-100)',hue='Cluster',data=df,palette='set1')
plt.title("hirerchical clustering of mall customers")
plt.show()

# %%
plt.figure(figsize=(10,6))
